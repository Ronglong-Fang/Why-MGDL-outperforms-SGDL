# %%
from sgdltwoLayerModifiedwithBias import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'results/R2/BEST/*.pickle'
# path = 'results/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)
    # print(file)

print(len(picklefile))

k=4
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainloss"):]), reverse=False)


for file in picklefile:
    print(file)

print('\n\n')

for i in range(5):
        
    file = picklefile[i]
    print(file)
    analysis(file)
# Out:
# 1
# results/R2/BEST/MGDLactirelu_grade4_epoch500000_learningrate2.00e-01_trainloss3.03e-02_valloss3.23e-02_testloss3.12e-02.pickle
#
#
#
# results/R2/BEST/MGDLactirelu_grade4_epoch500000_learningrate2.00e-01_trainloss3.03e-02_valloss3.23e-02_testloss3.12e-02.pickle
# the shape of image is: (128, 128)
# the shape of train Y is: (64, 64)
# the shape of test Y is: (128, 128)
# rel_error is 0.0007206739392131567
# at grade 1, train time: 306.4700593948364, train loss: 0.036450497806072235 val loss: 0.03555980324745178, test loss: 0.036431021988391876
# at grade 1, train time: 306.4700593948364, train psnr: 11.372665405273438 val psnr: 11.480106353759766, test psnr: 11.374985694885254
# rel_error is 0.0029721499886363745
# at grade 2, train time: 427.0707166194916, train loss: 0.033555515110492706 val loss: 0.03343099355697632, test loss: 0.033529214560985565
# at grade 2, train time: 427.0707166194916, train psnr: 11.732060432434082 val psnr: 11.74820613861084, test psnr: 11.735465049743652
# rel_error is 0.0004887721152044833
# at grade 3, train time: 604.5784542560577, train loss: 0.031818922609090805 val loss: 0.03305058181285858, test loss: 0.03197617828845978
# at grade 3, train time: 604.5784542560577, train psnr: 11.962844848632812 val psnr: 11.797908782958984, test psnr: 11.941433906555176
# rel_error is 0.0001599095994606614
# at grade 4, train time: 841.0272822380066, train loss: 0.030328765511512756 val loss: 0.03233303874731064, test loss: 0.031246066093444824
# at grade 4, train time: 841.0272822380066, train psnr: 12.171152114868164 val psnr: 11.893234252929688, test psnr: 12.041746139526367
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 21
#      17 print('\n\n')
#      19 for i in range(5):
# ---> 21     file = picklefile[i]
#      22     print(file)
#      23     analysis(file)
#
# IndexError: list index out of range
