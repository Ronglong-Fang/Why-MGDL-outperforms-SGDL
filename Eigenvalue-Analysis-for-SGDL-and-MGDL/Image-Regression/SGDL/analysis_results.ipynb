# %%
from sgdltwoLayerModifiedwithBias import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'results/*.pickle'
# path = 'results/BEST/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)
    # print(file)

print(len(picklefile))

k=3
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainloss"):]), reverse=False)

# k=5
# picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("testloss"):len("testloss3.8416e-03")]), reverse=False)


for file in picklefile:
    print(file)

print('\n\n\n')

for file in picklefile:
    print(file)
    analysis(file)
    print('\n\n\n')



# file0 = picklefile[0]
# print(file0)
# analysis(file0)

# file1 = picklefile[1]
# print(file1)
# analysis(file1)
# Out:
# 1
# results/SGDLactirelu_epoch500000_learningrate5.0000e-02_trainloss2.3600e-02_valloss3.0082e-02_testloss2.8251e-02.pickle
#
#
#
#
# results/SGDLactirelu_epoch500000_learningrate5.0000e-02_trainloss2.3600e-02_valloss3.0082e-02_testloss2.8251e-02.pickle
# the shape of image is: (128, 128)
# the shape of train Y is: (64, 64)
# the shape of test Y is: (128, 128)
# train time: 8810.890610218048, train loss: 0.023600365966558456 val loss: 0.0300816111266613, test loss: 0.02825147844851017
# train time: 8810.890610218048, train psnr: 13.260512351989746 val loss: 12.206687927246094, test psnr: 12.479287147521973
