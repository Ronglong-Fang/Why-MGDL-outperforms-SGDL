# %%
from sgdltwoLayerModifiedwithBias import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# path = 'results/R1/*.pickle'
path = 'results/BEST/*.pickle'
# path = 'results/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)
    # print(file)

print(len(picklefile))

k=6
picklefile = sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainloss"):]), reverse=False)

# k=7
# picklefile = sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainpsnr"):len("trainpsnr1.74e+01")]), reverse=True)


for file in picklefile:
    print(file)

print('\n\n')

for i in range(5):
        
    file = picklefile[i]
    print(file)
    analysis(file)
# Out:
# 1
# results/BEST/MGDLactirelu_grade4_epoch100000_learningrate5.00e-05_beta1.00e-03_lambd1.00e-04_trainloss3.42e+01_trainpsnr1.81e+01.pickle
#
#
#
# results/BEST/MGDLactirelu_grade4_epoch100000_learningrate5.00e-05_beta1.00e-03_lambd1.00e-04_trainloss3.42e+01_trainpsnr1.81e+01.pickle
# I am butterfly
# the shape of image is: (64, 64)
# the shape of train Y is: (64, 64)
# at grade 1, train time: 2447.1512520313263, train loss: 40.74538803100586 psnr: 17.31495475769043
# at grade 2, train time: 4843.175439357758, train loss: 37.37242126464844 psnr: 17.709213256835938
# at grade 3, train time: 7220.309766769409, train loss: 35.66627883911133 psnr: 17.927570343017578
# at grade 4, train time: 9597.586872339249, train loss: 34.24030685424805 psnr: 18.11430549621582
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 25
#      21 print('\n\n')
#      23 for i in range(5):
# ---> 25     file = picklefile[i]
#      26     print(file)
#      27     analysis(file)
#
# IndexError: list index out of range
