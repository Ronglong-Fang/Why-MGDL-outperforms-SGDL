# %%
from sgdltwoLayerModifiedwithBias import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'results/BEST/*.pickle'
# path = 'results/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)
    # print(file)

print(len(picklefile))

k=5
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainloss"):]), reverse=False)


for file in picklefile:
    print(file)

print('\n\n')

for i in range(5):
        
    file = picklefile[i]
    print(file)
    analysis(file)
# Out:
# 1
# results/BEST/SGDLactirelu_epoch100000_learningrate1.00e-05_beta1.00e-02_lambd7.00e-01_trainloss3.29e+01_trainpsnr1.83e+01.pickle
#
#
#
# results/BEST/SGDLactirelu_epoch100000_learningrate1.00e-05_beta1.00e-02_lambd7.00e-01_trainloss3.29e+01_trainpsnr1.83e+01.pickle
# I am butterfly
# the shape of image is: (64, 64)
# the shape of train Y is: (64, 64)
# train time: 17413.23705124855, train loss: 32.91762161254883 psnr: 18.26637840270996
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 21
#      17 print('\n\n')
#      19 for i in range(5):
# ---> 21     file = picklefile[i]
#      22     print(file)
#      23     analysis(file)
#
# IndexError: list index out of range
