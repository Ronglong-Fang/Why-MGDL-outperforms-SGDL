# %%
from sgdl import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'results/*.pickle'
# path = 'results/BEST/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)
    # print(file)

print(len(picklefile))

k=3
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainloss"):]), reverse=False)

# k=2
# picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("learningrate"):len("learningrate5.0000e-02")]), reverse=True)


for file in picklefile:
    print(file)

print('\n\n\n')

for file in picklefile:
    print(file)
    analysis(file)
    print('\n\n\n')



# file0 = picklefile[0]
# print(file0)
# analysis(file0)

# file1 = picklefile[1]
# print(file1)
# analysis(file1)
# Out:
# 5
# results/SGDLactirelu_epoch400000_learningrate5.0000e-03_trainloss5.2844e-03_valloss9.4905e-01.pickle
# results/SGDLactirelu_epoch400000_learningrate6.0000e-03_trainloss5.4144e-03_valloss9.6839e-01.pickle
# results/SGDLactirelu_epoch400000_learningrate3.0000e-03_trainloss7.0343e-03_valloss9.7720e-01.pickle
# results/SGDLactirelu_epoch400000_learningrate4.0000e-03_trainloss7.1275e-03_valloss9.4777e-01.pickle
# results/SGDLactirelu_epoch400000_learningrate2.0000e-03_trainloss1.0607e-02_valloss9.8861e-01.pickle
#
#
#
#
# results/SGDLactirelu_epoch400000_learningrate5.0000e-03_trainloss5.2844e-03_valloss9.4905e-01.pickle
# train_X shape: (10000, 3072), dtype: float32
# test_X shape: (10000, 3072), dtype: float32
# train_Y shape: (10000, 10), dtype: float32
# test_Y shape: (10000, 10), dtype: float32
# loss: 0.005535506177693605
# Accuracy: 99.93%
# train time: 104799.15353775024, train loss: 0.005284363403916359 val loss: 0.9490491151809692
# results/SGDLactirelu_epoch400000_learningrate6.0000e-03_trainloss5.4144e-03_valloss9.6839e-01.pickle
# train_X shape: (10000, 3072), dtype: float32
# test_X shape: (10000, 3072), dtype: float32
# train_Y shape: (10000, 10), dtype: float32
# test_Y shape: (10000, 10), dtype: float32
# loss: 0.005395316053181887
# Accuracy: 99.91%
# train time: 103591.85215640068, train loss: 0.0054143755696713924 val loss: 0.9683911800384521
# results/SGDLactirelu_epoch400000_learningrate3.0000e-03_trainloss7.0343e-03_valloss9.7720e-01.pickle
# train_X shape: (10000, 3072), dtype: float32
# test_X shape: (10000, 3072), dtype: float32
# train_Y shape: (10000, 10), dtype: float32
# test_Y shape: (10000, 10), dtype: float32
# loss: 0.007137902546674013
# Accuracy: 99.88%
# train time: 103803.87234044075, train loss: 0.007034309208393097 val loss: 0.9772005677223206
# results/SGDLactirelu_epoch400000_learningrate4.0000e-03_trainloss7.1275e-03_valloss9.4777e-01.pickle
# train_X shape: (10000, 3072), dtype: float32
# test_X shape: (10000, 3072), dtype: float32
# train_Y shape: (10000, 10), dtype: float32
# test_Y shape: (10000, 10), dtype: float32
# loss: 0.0071029881946742535
# Accuracy: 99.91%
# train time: 118677.07435464859, train loss: 0.007127485703676939 val loss: 0.9477702975273132
# results/SGDLactirelu_epoch400000_learningrate2.0000e-03_trainloss1.0607e-02_valloss9.8861e-01.pickle
# train_X shape: (10000, 3072), dtype: float32
# test_X shape: (10000, 3072), dtype: float32
# train_Y shape: (10000, 10), dtype: float32
# test_Y shape: (10000, 10), dtype: float32
# loss: 0.010334809310734272
# Accuracy: 99.87%
# train time: 104240.42012953758, train loss: 0.01060714665800333 val loss: 0.9886142611503601
