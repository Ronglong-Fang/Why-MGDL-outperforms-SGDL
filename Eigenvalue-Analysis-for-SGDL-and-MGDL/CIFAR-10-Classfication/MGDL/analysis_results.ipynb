# %%
from mgdl import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# path = 'results/Notuse/*.pickle'

path = 'results/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)
    # print(file)

print(len(picklefile))

k=3
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainloss"):]), reverse=False)


# k=3
# picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("learningrate"):]), reverse=True)

for file in picklefile:
    print(file)

print('\n\n')

for i in range(len(picklefile)):
        
    file = picklefile[i]
    print(file)
    analysis(file)
# Out:
# 6
# results/MGDLactirelu_grade4_learningrate4.00e-03_trainloss2.56e-03_valloss1.16e+00.pickle
# results/MGDLactirelu_grade4_learningrate3.00e-03_trainloss3.09e-03_valloss1.13e+00.pickle
# results/MGDLactirelu_grade4_learningrate5.00e-03_trainloss6.20e-03_valloss1.28e+00.pickle
# results/MGDLactirelu_grade4_learningrate2.00e-03_trainloss9.11e-03_valloss1.10e+00.pickle
# results/MGDLactirelu_grade4_learningrate6.00e-03_trainloss2.48e-02_valloss1.27e+00.pickle
# results/MGDLactirelu_grade4_learningrate1.00e-03_trainloss3.70e-02_valloss1.03e+00.pickle
#
#
#
# results/MGDLactirelu_grade4_learningrate4.00e-03_trainloss2.56e-03_valloss1.16e+00.pickle
# train_X shape: (10000, 3072), dtype: float32
# test_X shape: (10000, 3072), dtype: float32
# train_Y shape: (10000, 10), dtype: float32
# test_Y shape: (10000, 10), dtype: float32
# Accuracy: 94.97%
# at grade 1, train time: 34898.194036245346, train loss: 0.1411331295967102 val loss: 1.128136157989502, acc: 0.9496999979019165
# ...
