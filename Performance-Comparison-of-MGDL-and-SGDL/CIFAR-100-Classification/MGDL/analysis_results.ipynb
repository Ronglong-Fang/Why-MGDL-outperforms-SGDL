# %%
from mgdl import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# 2025-09-25 10:43:50.878609: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-25 10:43:51.648081: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-25 10:43:51.653469: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
path = 'results/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)
    # print(file)

print(len(picklefile))

k=3
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainloss"):]), reverse=False)


# k=3
# picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("learningrate"):]), reverse=True)

for file in picklefile:
    print(file)

print('\n\n')

for i in range(len(picklefile)):
        
    file = picklefile[i]
    print(file)
    analysis(file)
# Out:
# 0
