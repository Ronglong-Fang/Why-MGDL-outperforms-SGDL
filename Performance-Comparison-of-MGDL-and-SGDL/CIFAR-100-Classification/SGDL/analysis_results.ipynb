# %%
from sgdl import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'results/*.pickle'
# path = 'results/BEST/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)
    # print(file)

print(len(picklefile))

k=3
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("trainloss"):]), reverse=False)

# k=2
# picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("learningrate"):len("learningrate5.0000e-02")]), reverse=True)


for file in picklefile:
    print(file)

print('\n\n\n')

for file in picklefile:
    print(file)
    analysis(file)
    print('\n\n\n')



# file0 = picklefile[0]
# print(file0)
# analysis(file0)

# file1 = picklefile[1]
# print(file1)
# analysis(file1)
# Out:
# 7
# results/SGDLactirelu_epoch10000_learningrate2.0000e-04_trainloss9.4854e-03_valloss1.1677e+00.pickle
# results/SGDLactirelu_epoch10000_learningrate5.0000e-05_trainloss1.3967e-02_valloss9.0270e-01.pickle
# results/SGDLactirelu_epoch10000_learningrate1.0000e-04_trainloss1.4355e-02_valloss9.1301e-01.pickle
# results/SGDLactirelu_epoch10000_learningrate7.0000e-05_trainloss2.1748e-02_valloss9.0488e-01.pickle
# results/SGDLactirelu_epoch10000_learningrate3.0000e-04_trainloss6.5300e-02_valloss1.3498e+00.pickle
# results/SGDLactirelu_epoch10000_learningrate4.0000e-04_trainloss6.6665e-02_valloss1.1952e+00.pickle
# results/SGDLactirelu_epoch10000_learningrate5.0000e-04_trainloss1.0512e-01_valloss1.2670e+00.pickle
#
#
#
#
# results/SGDLactirelu_epoch10000_learningrate2.0000e-04_trainloss9.4854e-03_valloss1.1677e+00.pickle
# train_X shape: (10000, 32, 32, 3), dtype: float32
# test_X shape: (10000, 32, 32, 3), dtype: float32
# train_Y shape: (10000, 100), dtype: float32
# test_Y shape: float32, dtype: float32
# loss: 0.009394766762852669
# Accuracy: 99.11%
# train time: 42741.13777899742, train loss: 0.009485356509685516 val loss: 1.167731761932373
# results/SGDLactirelu_epoch10000_learningrate5.0000e-05_trainloss1.3967e-02_valloss9.0270e-01.pickle
# train_X shape: (10000, 32, 32, 3), dtype: float32
# test_X shape: (10000, 32, 32, 3), dtype: float32
# train_Y shape: (10000, 100), dtype: float32
# test_Y shape: float32, dtype: float32
# loss: 0.013995565474033356
# Accuracy: 98.73%
# train time: 36547.53717112541, train loss: 0.013966775499284267 val loss: 0.9026994109153748
# results/SGDLactirelu_epoch10000_learningrate1.0000e-04_trainloss1.4355e-02_valloss9.1301e-01.pickle
# train_X shape: (10000, 32, 32, 3), dtype: float32
# test_X shape: (10000, 32, 32, 3), dtype: float32
# train_Y shape: (10000, 100), dtype: float32
# test_Y shape: float32, dtype: float32
# loss: 0.01436193473637104
# Accuracy: 98.67%
# train time: 38527.85880899429, train loss: 0.014355351217091084 val loss: 0.9130134582519531
# results/SGDLactirelu_epoch10000_learningrate7.0000e-05_trainloss2.1748e-02_valloss9.0488e-01.pickle
# train_X shape: (10000, 32, 32, 3), dtype: float32
# test_X shape: (10000, 32, 32, 3), dtype: float32
# train_Y shape: (10000, 100), dtype: float32
# test_Y shape: float32, dtype: float32
# loss: 0.021939601749181747
# Accuracy: 97.95%
# train time: 35965.82436132431, train loss: 0.02174769528210163 val loss: 0.9048776030540466
# results/SGDLactirelu_epoch10000_learningrate3.0000e-04_trainloss6.5300e-02_valloss1.3498e+00.pickle
# train_X shape: (10000, 32, 32, 3), dtype: float32
# test_X shape: (10000, 32, 32, 3), dtype: float32
# train_Y shape: (10000, 100), dtype: float32
# test_Y shape: float32, dtype: float32
# loss: 0.06368710845708847
# Accuracy: 93.86%
# train time: 38578.606872320175, train loss: 0.06529968231916428 val loss: 1.3497979640960693
# results/SGDLactirelu_epoch10000_learningrate4.0000e-04_trainloss6.6665e-02_valloss1.1952e+00.pickle
# train_X shape: (10000, 32, 32, 3), dtype: float32
# test_X shape: (10000, 32, 32, 3), dtype: float32
# train_Y shape: (10000, 100), dtype: float32
# test_Y shape: float32, dtype: float32
# loss: 0.06486136466264725
# Accuracy: 94.32%
# train time: 38911.724401474, train loss: 0.06666456907987595 val loss: 1.1951885223388672
# results/SGDLactirelu_epoch10000_learningrate5.0000e-04_trainloss1.0512e-01_valloss1.2670e+00.pickle
# train_X shape: (10000, 32, 32, 3), dtype: float32
# test_X shape: (10000, 32, 32, 3), dtype: float32
# train_Y shape: (10000, 100), dtype: float32
# test_Y shape: float32, dtype: float32
# loss: 0.11217713356018066
# Accuracy: 90.28%
# train time: 38088.77217888832, train loss: 0.10511618107557297 val loss: 1.2670460939407349
