# %%
from transformer_utils import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'results/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)

print(len(picklefile))
k=4
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("TeMSE"):len("TeMSE5.90e-01")]), reverse=False)

for file in picklefile:
    print(file)

print(f"****************************")
for file in picklefile:
    print(file)
    analysis(file)
    print('\n\n\n')
# Out:
# 5
# results/SGDLTransformer_epoch300_lr1.00e-03_TrMse7.09e-02_TeMse2.55e+00.pickle
# results/SGDLTransformer_epoch300_lr7.00e-04_TrMse8.60e-02_TeMse3.57e+00.pickle
# results/SGDLTransformer_epoch300_lr5.00e-04_TrMse4.50e-02_TeMse4.12e+00.pickle
# results/SGDLTransformer_epoch300_lr3.00e-04_TrMse1.32e-02_TeMse4.80e+00.pickle
# results/SGDLTransformer_epoch300_lr1.00e-04_TrMse8.29e-02_TeMse8.78e+00.pickle
# ****************************
# results/SGDLTransformer_epoch300_lr1.00e-03_TrMse7.09e-02_TeMse2.55e+00.pickle
# TrMSE: 0.0709422156214714, TeMSE: 2.5512640476226807, Time: 2693.2540290355682
# n_test: 452, 387
# results/SGDLTransformer_epoch300_lr7.00e-04_TrMse8.60e-02_TeMse3.57e+00.pickle
# TrMSE: 0.08598751574754715, TeMSE: 3.570279359817505, Time: 2555.9547522068024
# n_test: 452, 387
# results/SGDLTransformer_epoch300_lr5.00e-04_TrMse4.50e-02_TeMse4.12e+00.pickle
# TrMSE: 0.04495453089475632, TeMSE: 4.117363452911377, Time: 2617.1300060749054
# n_test: 452, 387
# results/SGDLTransformer_epoch300_lr3.00e-04_TrMse1.32e-02_TeMse4.80e+00.pickle
# TrMSE: 0.013225585222244263, TeMSE: 4.8003082275390625, Time: 2571.911876440048
# n_test: 452, 387
# results/SGDLTransformer_epoch300_lr1.00e-04_TrMse8.29e-02_TeMse8.78e+00.pickle
# TrMSE: 0.08290644735097885, TeMSE: 8.784625053405762, Time: 2595.599992752075
# n_test: 452, 387
