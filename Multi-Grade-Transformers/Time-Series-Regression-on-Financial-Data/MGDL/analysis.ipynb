# %%
from transformer_utils import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'results/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)

print(len(picklefile))
k=5
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("TeMSE"):len("TeMSE5.90e-01")]), reverse=False)

for file in picklefile:
    print(file)

print(f"************************************")

predict = True
file = picklefile[0]
analysis(file, predict)
# print('\n\n\n')
# predict = False
# for file in picklefile:
#     print(file)
#     analysis(file, predict)
#     print('\n\n\n')
# Out:
# 12
# results/MGDL_grade6_epoch30_TrMse8.14e-04_VaMSE9.63e-04_TeMSE1.85e-02.pickle
# results/MGDL_grade6_epoch30_TrMse6.45e-04_VaMSE7.53e-04_TeMSE3.00e-02.pickle
# results/MGDL_grade6_epoch30_TrMse9.02e-04_VaMSE1.13e-03_TeMSE1.47e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.69e-04_VaMSE8.97e-04_TeMSE2.46e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.65e-04_VaMSE8.93e-04_TeMSE2.61e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.68e-04_VaMSE9.08e-04_TeMSE2.88e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.52e-04_VaMSE8.25e-04_TeMSE3.29e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.54e-04_VaMSE8.17e-04_TeMSE3.96e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.39e-04_VaMSE8.26e-04_TeMSE4.21e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.67e-04_VaMSE8.42e-04_TeMSE4.27e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.16e-04_VaMSE8.29e-04_TeMSE5.20e-01.pickle
# results/MGDL_grade6_epoch30_TrMse6.49e-04_VaMSE8.32e-04_TeMSE5.21e-01.pickle
# ************************************
# ...
