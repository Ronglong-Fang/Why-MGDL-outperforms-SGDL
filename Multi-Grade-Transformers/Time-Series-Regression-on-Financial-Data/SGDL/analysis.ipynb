# %%
from transformer_utils import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
path = 'results/*.pickle'
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file)

print(len(picklefile))
k = 5
picklefile = sorted(picklefile, key=lambda x: float(x.split('_')[k][len("TeMSE"):len("TeMSE5.90e-01")]), reverse=False)

for file in picklefile:
    print(file)

print(f"****************************")

predict = True
file = picklefile[0]
analysis(file, predict)

# print('\n\n\n')
# predict = False
# for file in picklefile:
#     print(file)
#     analysis(file, predict)
#     print('\n\n\n')
# Out:
# 7
# results/SGDLTransformer_epoch30_lr5.00e-03_TrMse1.75e-03_VaMse1.96e-03_TeMse8.86e-02.pickle
# results/SGDLTransformer_epoch30_lr3.00e-03_TrMse1.09e-03_VaMse1.24e-03_TeMse1.13e-01.pickle
# results/SGDLTransformer_epoch30_lr1.00e-03_TrMse8.19e-04_VaMse9.67e-04_TeMse1.53e-01.pickle
# results/SGDLTransformer_epoch30_lr7.00e-04_TrMse1.14e-03_VaMse1.29e-03_TeMse1.81e-01.pickle
# results/SGDLTransformer_epoch30_lr5.00e-04_TrMse8.25e-04_VaMse1.03e-03_TeMse2.27e-01.pickle
# results/SGDLTransformer_epoch30_lr3.00e-04_TrMse9.83e-04_VaMse1.22e-03_TeMse2.67e-01.pickle
# results/SGDLTransformer_epoch30_lr1.00e-04_TrMse1.04e-03_VaMse1.35e-03_TeMse4.53e-01.pickle
# ****************************
# TrMSE: 0.0017534669023007154, ValMSE: 0.0019568155985325575, TeMSE: 0.08863475173711777, Time: 1742.4104368686676
# MSE (train+val): 0.000238, baseline: 0.000151
# MSE (test): 0.000134, baseline: 0.000127
